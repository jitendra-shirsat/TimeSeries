# %%
import numpy as np
import sys

# %%
data = np.genfromtxt('/Users/jitendrashirsat/Documents/AWS_Euro_Millions/Full_Data_Euro_Millions.csv' ,
                     dtype=np.uint16,delimiter =',',usecols=[0,1,2,3,4,5,6,7],
                    skip_header = 1)

# %%
sys.getsizeof(data)
# Out:
# 1704

# %%
data
# Out:
# array([[ 1,  2,  3,  4,  5,  1,  2, 18],
#        [ 1,  2,  3,  4,  5,  1,  3, 19],
#        [ 1,  2,  3,  4,  5,  1,  4, 20],
#        [ 1,  2,  3,  4,  5,  1,  5, 21],
#        [ 1,  2,  3,  4,  5,  1,  6, 22],
#        [ 1,  2,  3,  4,  5,  1,  7, 23],
#        [ 1,  2,  3,  4,  5,  1,  8, 24],
#        [ 1,  2,  3,  4,  5,  1,  9, 25],
#        [ 1,  2,  3,  4,  5,  1, 10, 26],
#        [ 1,  2,  3,  4,  5,  1, 11, 27],
#        [ 1,  2,  3,  4,  5,  1, 12, 28],
#        [ 1,  2,  3,  4,  5,  2,  3, 20],
#        [ 1,  2,  3,  4,  5,  2,  4, 21],
#        [ 1,  2,  3,  4,  5,  2,  5, 22],
#        [ 1,  2,  3,  4,  5,  2,  6, 23],
#        [ 1,  2,  3,  4,  5,  2,  7, 24],
#        [ 1,  2,  3,  4,  5,  2,  8, 25],
#        [ 1,  2,  3,  4,  5,  2,  9, 26],
#        [ 1,  2,  3,  4,  5,  2, 10, 27],
#        [ 1,  2,  3,  4,  5,  2, 11, 28],
#        [ 1,  2,  3,  4,  5,  2, 12, 29],
#        [ 1,  2,  3,  4,  5,  3,  4, 22],
#        [ 1,  2,  3,  4,  5,  3,  5, 23],
# ...
