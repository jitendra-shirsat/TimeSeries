# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import boxcox
from scipy.special import inv_boxcox

# %%
df = pd.read_csv(r'/Users/jitendrashirsat/Documents/Time-Series/TimeSeries/Last_Five_years_Lotto.csv'\
                ,index_col='RDate',parse_dates=True)

# %%
df.head(5)
# Out:
#              Key_id  First_P  Second_P  Third_P  Fourth_P  Fifth_P  Sixth_P  \
# RDate
# 2016-01-02  8302779       10        19       23        28       31       32
# 2016-01-06  2383816        2        15       25        43       45       46
# 2016-01-09  2173466        2        11       14        28       29       34
# 2016-01-13  8169338       10        14       26        37       42       47
# 2016-01-16  9502701       14        18       25        27       33       44
#
#            Result  Total    Product
# RDate
# 2016-01-02   Roll    143  121381120
# 2016-01-06   Roll    176   66757500
# 2016-01-09   Roll    118    8503264
# 2016-01-13   Roll    176  265858320
# 2016-01-16   Roll    161  246985200

# %%
df['Total'].plot(figsize=(20,8))
# Out:
# <AxesSubplot:xlabel='RDate'>

# %%
df['SqrtTotal'] = np.sqrt(df['Total'])
df['SqrtTotal'].plot(figsize=(20,8))
# Out:
# <AxesSubplot:xlabel='RDate'>

# %%
df['LogTotal'] = np.log(df['Total'])
df['LogTotal'].plot(figsize=(20,8))
# Out:
# <AxesSubplot:xlabel='RDate'>

# %%
df.head(6)
# Out:
#              Key_id  First_P  Second_P  Third_P  Fourth_P  Fifth_P  Sixth_P  \
# RDate
# 2016-01-02  8302779       10        19       23        28       31       32
# 2016-01-06  2383816        2        15       25        43       45       46
# 2016-01-09  2173466        2        11       14        28       29       34
# 2016-01-13  8169338       10        14       26        37       42       47
# 2016-01-16  9502701       14        18       25        27       33       44
# 2016-01-20  2899486        3         6       17        23       27       29
#
#            Result  Total    Product  SqrtTotal  LogTotal
# RDate
# 2016-01-02   Roll    143  121381120  11.958261  4.962845
# 2016-01-06   Roll    176   66757500  13.266499  5.170484
# 2016-01-09   Roll    118    8503264  10.862780  4.770685
# 2016-01-13   Roll    176  265858320  13.266499  5.170484
# 2016-01-16   Roll    161  246985200  12.688578  5.081404
# 2016-01-20   Roll    105    5510754  10.246951  4.653960

# %%
data , lam = boxcox(df['Total'])
df['BoxCoxTotal'] = data
df['BoxCoxTotal'].plot(figsize=(20,8))
# Out:
# <AxesSubplot:xlabel='RDate'>

# %%
df['Total'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
df['SqrtTotal'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
df['LogTotal'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
df['BoxCoxTotal'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # take the last 104 samples which is one year

# %%
df100 = df[-104:].copy()

# %%
df100
# Out:
#               Key_id  First_P  Second_P  Third_P  Fourth_P  Fifth_P  Sixth_P  \
# RDate
# 2021-07-03  10712402       29        30       36        38       44       45
# 2021-07-07   4515569        4        18       26        30       31       37
# 2021-07-10  10125684       17        27       30        35       42       47
# 2021-07-14   3116381        3         9       11        27       29       47
# 2021-07-17   8932466       12        16       23        26       34       45
# ...              ...      ...       ...      ...       ...      ...      ...
# 2022-06-15   6851760        7        23       27        38       46       47
# 2022-06-18   4455117        4        16       21        27       45       47
# 2022-06-22   3490698        3        16       20        34       35       37
# 2022-06-25   1837284        2         6       27        28       41       45
# 2022-06-29    839715        1         9       17        25       30       31
#
# ...

# %%
df100['Total'].plot(figsize=(20,8))
# Out:
# <AxesSubplot:xlabel='RDate'>

# %%
df100['Total'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
df100['SqrtTotal'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
df100['LogTotal'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
df100['BoxCoxTotal'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Below is for Product

# %%
df['Product'].plot(figsize=(20,8))
# Out:
# <AxesSubplot:xlabel='RDate'>

# %%
df['SqrtProduct'] = np.sqrt(df['Product'])
df['SqrtProduct'].plot(figsize=(20,8))
# Out:
# <AxesSubplot:xlabel='RDate'>

# %%
df['LogProduct'] = np.log(df['Product'])
df['LogProduct'].plot(figsize=(20,8))
# Out:
# <AxesSubplot:xlabel='RDate'>

# %%
data , lam = boxcox(df['Product'])
df['BoxCoxProduct'] = data
df['BoxCoxProduct'].plot(figsize=(20,8))
# Out:
# <AxesSubplot:xlabel='RDate'>

# %%
lam
# Out:
# 0.04902427257987969

# %%
df['Product'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
df['SqrtProduct'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
df['LogProduct'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
df['BoxCoxProduct'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Inverse BoxCox

# %%
# df.drop(['First_P','Second_P','Third_P','Fourth_P','Fifth_P','Sixth_P'], axis=1,inplace=True)

# %%
df
# Out:
#              Key_id Result  Total    Product   SqrtProduct  LogProduct  \
# RDate
# 2016-01-02  8302779   Roll    143  121381120  11017.310017   18.614446
# 2016-01-06  2383816   Roll    176   66757500   8170.526299   18.016577
# 2016-01-09  2173466   Roll    118    8503264   2916.035665   15.955961
# 2016-01-13  8169338   Roll    176  265858320  16305.162373   19.398474
# 2016-01-16  9502701   Roll    161  246985200  15715.762788   19.324839
# ...             ...    ...    ...        ...           ...         ...
# 2022-06-15  6851760   Roll    188  357132132  18897.939888   19.693616
# 2022-06-18  4455117   Roll    160   76749120   8760.657510   18.156052
# 2022-06-22  3490698   Roll    145   42268800   6501.445993   17.559560
# 2022-06-25  1837284   Roll    149   16737840   4091.190536   16.633183
# 2022-06-29   839715   Roll    113    3557250   1886.067337   15.084498
#
#             BoxCoxProduct
# RDate
# 2016-01-02      30.407177
# 2016-01-06      28.939683
# ...

# %%
df['Reverted_Product'] = inv_boxcox(df['BoxCoxProduct'],0.04902427257987969 )

# %%
df
# Out:
#              Key_id Result  Total    Product   SqrtProduct  LogProduct  \
# RDate
# 2016-01-02  8302779   Roll    143  121381120  11017.310017   18.614446
# 2016-01-06  2383816   Roll    176   66757500   8170.526299   18.016577
# 2016-01-09  2173466   Roll    118    8503264   2916.035665   15.955961
# 2016-01-13  8169338   Roll    176  265858320  16305.162373   19.398474
# 2016-01-16  9502701   Roll    161  246985200  15715.762788   19.324839
# ...             ...    ...    ...        ...           ...         ...
# 2022-06-15  6851760   Roll    188  357132132  18897.939888   19.693616
# 2022-06-18  4455117   Roll    160   76749120   8760.657510   18.156052
# 2022-06-22  3490698   Roll    145   42268800   6501.445993   17.559560
# 2022-06-25  1837284   Roll    149   16737840   4091.190536   16.633183
# 2022-06-29   839715   Roll    113    3557250   1886.067337   15.084498
#
#             BoxCoxProduct  Reverted_Product
# RDate
# 2016-01-02      30.407177      1.213811e+08
# ...
